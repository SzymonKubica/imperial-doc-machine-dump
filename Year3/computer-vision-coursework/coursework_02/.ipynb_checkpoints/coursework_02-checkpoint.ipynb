# %% [markdown]
# # Coursework 2: Image segmentation
#
# In this coursework you will develop and train a convolutional neural network for brain tumour image segmentation. Please read both the text and the code in this notebook to get an idea what you are expected to implement. Pay attention to the missing code blocks that look like this:
#
# ```
# ### Insert your code ###
# ...
# ### End of your code ###
# ```
#
# ## What to do?
#
# * Complete and run the code using `jupyter-lab` or `jupyter-notebook` to get the results.
#
# * Export (File | Save and Export Notebook As...) the notebook as a PDF file, which contains your code, results and answers, and upload the PDF file onto [Scientia](https://scientia.doc.ic.ac.uk).
#
# * Instead of clicking the Export button, you can also run the following command instead: `jupyter nbconvert coursework.ipynb --to pdf`
#
# * If Jupyter complains about some problems in exporting, it is likely that pandoc (https://pandoc.org/installing.html) or latex is not installed, or their paths have not been included. You can install the relevant libraries and retry.
#
# * If Jupyter-lab does not work for you at the end, you can use Google Colab to write the code and export the PDF file.
#
# ## Dependencies
#
# You need to install Jupyter-Lab (https://jupyterlab.readthedocs.io/en/stable/getting_started/installation.html) and other libraries used in this coursework, such as by running the command:
# `pip3 install [package_name]`
#
# ## GPU resource
#
# The coursework is developed to be able to run on CPU, as all images have been pre-processed to be 2D and of a smaller size, compared to original 3D volumes.
#
# However, to save training time, you may want to use GPU. In that case, you can run this notebook on Google Colab. On Google Colab, go to the menu, Runtime - Change runtime type, and select **GPU** as the hardware acceleartor. At the end, please still export everything and submit as a PDF file on Scientia.

# %%
# Import libraries
# These libraries should be sufficient for this tutorial.
# However, if any other library is needed, please install by yourself.
import tarfile
import imageio.v3
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
import numpy as np
import time
import os
import random
import matplotlib.pyplot as plt
from matplotlib import colors

# %% [markdown]
# ## 1. Download and visualise the imaging dataset.
#
# The dataset is curated from the brain imaging dataset in [Medical Decathlon Challenge](http://medicaldecathlon.com/). To save the storage and reduce the computational cost for this tutorial, we extract 2D image slices from T1-Gd contrast enhanced 3D brain volumes and downsample the images.
#
# The dataset consists of a training set and a test set. Each image is of dimension 120 x 120, with a corresponding label map of the same dimension. There are four number of classes in the label map:
#
# - 0: background
# - 1: edema
# - 2: non-enhancing tumour
# - 3: enhancing tumour

# %%
# Download the dataset
# !wget https://www.dropbox.com/s/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz

# Unzip the '.tar.gz' file to the current directory
datafile = tarfile.open('Task01_BrainTumour_2D.tar.gz')
datafile.extractall()
datafile.close()
# Out:
# --2023-02-22 21:30:22--  https://www.dropbox.com/s/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.64.18, 2620:100:6020:18::a27d:4012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.64.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz [following]
# --2023-02-22 21:30:22--  https://www.dropbox.com/s/raw/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com/cd/0/inline/B3D2HWTw18U-J_6CfKD3SEyVaovq_V0yjHBauxMnti-vnq6d8soUnzoVFKaWRqXECdMGgVQt8a75HkeyIlyGIB29fd_MEK0oQKYAnFTr3c09i2gW8X9UXOJB8fAOr4cdm1vgGb_IpqZ3Z-HfkOjL9hW0WitQ38pJFP_cLq5rHsuHog/file# [following]
# --2023-02-22 21:30:23--  https://uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com/cd/0/inline/B3D2HWTw18U-J_6CfKD3SEyVaovq_V0yjHBauxMnti-vnq6d8soUnzoVFKaWRqXECdMGgVQt8a75HkeyIlyGIB29fd_MEK0oQKYAnFTr3c09i2gW8X9UXOJB8fAOr4cdm1vgGb_IpqZ3Z-HfkOjL9hW0WitQ38pJFP_cLq5rHsuHog/file
# Resolving uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com (uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com)... 162.125.64.15, 2620:100:6020:15::a27d:400f
# Connecting to uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com (uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/B3A3McXrYGd_oT9nkgDw_tj-kBz22HD8ob7_QtQJgF3Wf2O9JZOQIPIN6cb_MnIdSILfmuQAeqjtmliyrBDqDHsdjQGFrMwa0u5E9nhqyLmi76Jsk8w-RO4npFgfWQLHSS9sR_cckeft1ThUIqmnbvxwgnvuFmKAvQwGY7HtoWLzm8_-DLXcDmBXePEj8_nB7N9TIQzvHIrDF9gW6ai1bwNiPWD-Q3FF5NNzvbP1enxbaS8lI9cQ18eV3qCb4Fc6nuNjDkWydGjwhNUesRpjNnqbxNd4HIUJYp79Lz8udGzC6M8pzWD9qiRY2NE388IxV3RBUZperUUOVWwrZ1-AkEXSKe5brVrBNJNAJpUYqbJtFMDr6vMymADxbsboBgonScF67Rbv8kvgV3ApuQ2dGWtOb2R-ckJPRseV3OvPIy0YGw/file [following]
# --2023-02-22 21:30:24--  https://uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com/cd/0/inline2/B3A3McXrYGd_oT9nkgDw_tj-kBz22HD8ob7_QtQJgF3Wf2O9JZOQIPIN6cb_MnIdSILfmuQAeqjtmliyrBDqDHsdjQGFrMwa0u5E9nhqyLmi76Jsk8w-RO4npFgfWQLHSS9sR_cckeft1ThUIqmnbvxwgnvuFmKAvQwGY7HtoWLzm8_-DLXcDmBXePEj8_nB7N9TIQzvHIrDF9gW6ai1bwNiPWD-Q3FF5NNzvbP1enxbaS8lI9cQ18eV3qCb4Fc6nuNjDkWydGjwhNUesRpjNnqbxNd4HIUJYp79Lz8udGzC6M8pzWD9qiRY2NE388IxV3RBUZperUUOVWwrZ1-AkEXSKe5brVrBNJNAJpUYqbJtFMDr6vMymADxbsboBgonScF67Rbv8kvgV3ApuQ2dGWtOb2R-ckJPRseV3OvPIy0YGw/file
# Reusing existing connection to uc57cf89c82a5acc4fdcb6238ffe.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9251149 (8.8M) [application/octet-stream]
# Saving to: ‘Task01_BrainTumour_2D.tar.gz.2’
#
# Task01_BrainTumour_ 100%[===================>]   8.82M  4.34MB/s    in 2.0s
#
# 2023-02-22 21:30:26 (4.34 MB/s) - ‘Task01_BrainTumour_2D.tar.gz.2’ saved [9251149/9251149]

# %% [markdown]
# Suggested colour map for brain MR image:
# ```
# cmap = 'gray'
# ```
#
# Suggested colour map for segmentation map:
# ```
# cmap = colors.ListedColormap(['black', 'green', 'blue', 'red'])
# ```

# %%
from pathlib import Path

IMAGES_DIR = Path('./Task01_BrainTumour_2D')

TRAINING_IMAGES_DIR = IMAGES_DIR / 'training_images/'
TRAINING_LABELS_DIR = IMAGES_DIR / 'training_labels/'

def extract_images_from(dir_path):
    images = {}
    for file in dir_path.iterdir():
        if not file.is_file():
            continue
        images[file.name] = imageio.v3.imread(file)
    return images
        
training_images_dict = extract_images_from(TRAINING_IMAGES_DIR)
training_labels_dict = extract_images_from(TRAINING_LABELS_DIR)

def zip_images_and_labels(image_dict, label_dict):
    pairs = []
    for file_name in image_dict.keys():
        pairs.append((image_dict[file_name], label_dict[file_name]))
    return pairs

images_with_labels = zip_images_and_labels(training_images_dict, training_labels_dict)
    
NUMBER_OF_IMAGES_TO_VISUALISE = 4

images_with_labels = random.sample(images_with_labels, NUMBER_OF_IMAGES_TO_VISUALISE)

# For visualising the labels, the following color map was used
# 0 -> 'black' : background
# 1 -> 'green' : edema
# 2 -> 'blue'  : non-enhancing tumour
# 3 -> 'red'   : enhancing tumour
def visualise(images_with_labels):
    figure = plt.figure(figsize=(8, 8))
    columns = 2 # In each row we visualise the image and its labels.
    rows = len(images_with_labels)
    for i, (image, labels) in enumerate(images_with_labels):
        figure.add_subplot(rows, columns, 2*i + 1)
        plt.imshow(image, cmap='gray')
        plt.gcf().set_size_inches(8, 8)
        figure.add_subplot(rows, columns, 2*i + 2)
        plt.imshow(labels, cmap=colors.ListedColormap(['black', 'green', 'blue', 'red']))
        plt.gcf().set_size_inches(8, 8)
        
    plt.show()
        
visualise(images_with_labels)

# %% [markdown]
# ## 2. Implement a dataset class.
#
# It can read the imaging dataset and get items, pairs of images and label maps, as training batches.

# %%
def normalise_intensity(image, thres_roi=1.0):
    """ Normalise the image intensity by the mean and standard deviation """
    # ROI defines the image foreground
    val_l = np.percentile(image, thres_roi)
    roi = (image >= val_l)
    mu, sigma = np.mean(image[roi]), np.std(image[roi])
    eps = 1e-6
    image2 = (image - mu) / (sigma + eps)
    return image2


class BrainImageSet(Dataset):
    """ Brain image set """
    def __init__(self, image_path, label_path='', deploy=False):
        self.image_path = Path(image_path)
        self.label_path = Path(label_path)
        self.deploy = deploy
        self.images = []
        self.labels = []

        images_dict = extract_images_from(self.image_path)
        
        # Swapped the code for reading in images because the imageio.v3 library
        # was complaining about it.
        if not self.deploy:
            labels_dict = extract_images_from(self.label_path)
            images_with_labels = zip_images_and_labels(images_dict, labels_dict)
            images, labels = list(zip(*images_with_labels))
            # Needed to reshape the array here so that pytorch deals with it correctly.
            self.images = np.array([np.reshape(image, (1, 120, 120)) for image in images])
            self.labels = np.array([np.reshape(label, (1, 120, 120)) for label in labels])
        else:
            self.images = images.values()
        
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Get an image and perform intensity normalisation
        # Dimension: XY
        image = normalise_intensity(self.images[idx])

        # Get its label map
        # Dimension: XY
        label = self.labels[idx]
        return image, label

    def get_random_batch(self, batch_size):
        # Get a batch of paired images and label maps
        # Dimension of images: NCXY
        # Dimension of labels: NXY
        images, labels = [], []

        random_indices = random.sample(range(len(self)), batch_size)
        
        for idx in random_indices:
            image, label = self[idx]
            images.append(image)
            labels.append(label)
        return np.array(images), np.array(labels)

# %% [markdown]
# ## 3. Build a U-net architecture.
#
# You will implement a U-net architecture. If you are not familiar with U-net, please read this paper:
#
# [1] Olaf Ronneberger et al. [U-Net: Convolutional networks for biomedical image segmentation](https://link.springer.com/chapter/10.1007/978-3-319-24574-4_28). MICCAI, 2015.
#
# For the first convolutional layer, you can start with 16 filters. We have implemented the encoder path. Please complete the decoder path.

# %%
""" U-net """
class UNet(nn.Module):
    def __init__(self, input_channel=1, output_channel=1, num_filter=16):
        super(UNet, self).__init__()

        # BatchNorm: by default during training this layer keeps running estimates
        # of its computed mean and variance, which are then used for normalization
        # during evaluation.

        # Encoder path
        n = num_filter  # 16
        self.conv1 = nn.Sequential(
            nn.Conv2d(input_channel, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 32
        self.conv2 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 64
        self.conv3 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 128
        self.conv4 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )
        
        # The first step in each one of conv2 conv3 conv4 above is the max pooling
        # for the decode step we need to perform up-conv 2x2 and then the rest
        # of the structure remains the same (BatchNorm2d -> ReLU -> Conv2d -> BatchNorm2d -> ReLU)
        
        # Each of the decode steps also needs to take the skipped input.
        # In the paper it was stated that they used an up-convolution using a 
        # learned kernel. It means that we need to use ConvTranspose2d to have
        # a trainable weight on that layer (rather than using e.g. a simple upsampling).
        
        # In the following we need to split the layers as the U-Net takes the skipped
        # outputs from the previous convolution layers and concatenates them with 
        # the intermediate steps. Therefore we need to perform upconvolution and the 
        # regular conv 3x3 ReLU steps separately.
        
        # Decoder path
        # We decrease the number of output channels.
        n = int(n / 2) # 64
        self.upconv1 = nn.Sequential(
            nn.ConvTranspose2d(n * 2, n, kernel_size=2, stride=2),
            nn.BatchNorm2d(n),
            nn.ReLU(),
        )
        # This one takes in the concatenated input therefore it will still have n*2 input channels.
        self.conv5 = nn.Sequential(
            nn.Conv2d(n*2, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )
        
        n = int(n / 2) # 32
        self.upconv2 = nn.Sequential(
            nn.ConvTranspose2d(n * 2, n, kernel_size=2, stride=2),
            nn.BatchNorm2d(n),
            nn.ReLU(),
        )
        
        self.conv6 = nn.Sequential(
            nn.Conv2d(n*2, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n = int(n / 2) # 16
        self.upconv3 = nn.Sequential(
            nn.ConvTranspose2d(n * 2, n, kernel_size=2, stride=2),
            nn.BatchNorm2d(n),
            nn.ReLU(),
        )
        
        # For the output layer we need conv 1x1 as described in the paper
        NUMBER_OF_CLASSES = 4 # Need a separate output for each class.
        self.conv7 = nn.Sequential(
            nn.Conv2d(n*2, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, NUMBER_OF_CLASSES, kernel_size=1)
        )
        
        

    def forward(self, x):
        # Use the convolutional operators defined above to build the U-net
        # The encoder part is already done for you.
        # You need to complete the decoder part.
        # Encoder
        x = self.conv1(x)
        conv1_skip = x

        x = self.conv2(x)
        conv2_skip = x

        x = self.conv3(x)
        conv3_skip = x

        x = self.conv4(x)
        
        # Decoder
        
        # First we perform up-convolution and then concatenate with the skipped values
        # Question: does the order of concatenation matter?
        # After concatenation we perform the regular conv 3x3 ReLU.
        
        x = self.upconv1(x)
        x = torch.cat((conv3_skip, x), 1)
        x = self.conv5(x)
        
        x = self.upconv2(x)
        x = torch.cat((conv2_skip, x), 1)
        x = self.conv6(x)
        
        x = self.upconv3(x)
        x = torch.cat((conv1_skip, x), 1)
        x = self.conv7(x)
        
        return x

# %% [markdown]
# ## 4. Train the segmentation model.

# %%
# CUDA device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device: {0}'.format(device))

# Build the model
num_class = 4
model = UNet(input_channel=1, output_channel=num_class, num_filter=16)
model = model.to(device)
params = list(model.parameters())

model_dir = 'saved_models'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Optimizer
optimizer = optim.Adam(params, lr=1e-3)

# Segmentation loss
criterion = nn.CrossEntropyLoss()

# Datasets
train_set = BrainImageSet('./Task01_BrainTumour_2D/training_images/', './Task01_BrainTumour_2D/training_labels/')
test_set = BrainImageSet('./Task01_BrainTumour_2D/test_images/', './Task01_BrainTumour_2D/test_labels/')

# Train the model
# Note: when you debug the model, you may reduce the number of iterations or batch size to save time.
num_iter = 10000
train_batch_size = 16
eval_batch_size = 16
start = time.time()

for it in range(1, 1 + num_iter):
    # Set the modules in training mode, which will have effects on certain modules, e.g. dropout or batchnorm.
    start_iter = time.time()
    model.train()

    # Get a batch of images and labels
    images, labels = train_set.get_random_batch(train_batch_size)
    images, labels = torch.from_numpy(images), torch.from_numpy(labels)
    images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)

    # Perform optimisation and print out the training loss
    optimizer.zero_grad()
    output = model(images)
    loss = criterion(torch.squeeze(output), torch.squeeze(labels))
    loss.backward()
    optimizer.step()
    print("Iteration: {}, Training loss: {}".format(it, loss.item()))

    # Evaluate
    if it % 100 == 0:
        model.eval()
        # Disabling gradient calculation during reference to reduce memory consumption
        with torch.no_grad():
            # Evaluate on a batch of test images and print out the test loss
            images, labels = test_set.get_random_batch(train_batch_size)
            images, labels = torch.from_numpy(images), torch.from_numpy(labels)
            images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
            output = model(images)
            loss = criterion(torch.squeeze(output), torch.squeeze(labels))
            print("Iteration: {}, Test loss: {}".format(it, loss.item()))
 

    # Save the model
    if it % 1000 == 0:
        torch.save(model.state_dict(), os.path.join(model_dir, 'model_{0}.pt'.format(it)))
print('Training took {:.3f}s in total.'.format(time.time() - start))
# Out:
# Device: cpu
# Iteration: 1, Training loss: 1.5365246534347534
# Iteration: 2, Training loss: 1.4704378843307495
# Iteration: 3, Training loss: 1.4355077743530273
# Iteration: 4, Training loss: 1.3967204093933105
# Iteration: 5, Training loss: 1.379899501800537
# Iteration: 6, Training loss: 1.3496159315109253
# Iteration: 7, Training loss: 1.3183681964874268
# Iteration: 8, Training loss: 1.307318091392517
# Iteration: 9, Training loss: 1.2856245040893555
# Iteration: 10, Training loss: 1.2725839614868164
# Iteration: 11, Training loss: 1.2582112550735474
# Iteration: 12, Training loss: 1.230186104774475
# Iteration: 13, Training loss: 1.2281510829925537
# Iteration: 14, Training loss: 1.2037591934204102
# Iteration: 15, Training loss: 1.1890467405319214
# Iteration: 16, Training loss: 1.1761771440505981
# Iteration: 17, Training loss: 1.168394684791565
# Iteration: 18, Training loss: 1.1464810371398926
# Iteration: 19, Training loss: 1.1354056596755981
# Iteration: 20, Training loss: 1.1224253177642822
# Iteration: 21, Training loss: 1.1086474657058716
# Iteration: 22, Training loss: 1.0932931900024414
# Iteration: 23, Training loss: 1.0886404514312744
# Iteration: 24, Training loss: 1.075095534324646
# Iteration: 25, Training loss: 1.0597330331802368
# Iteration: 26, Training loss: 1.0444327592849731
# Iteration: 27, Training loss: 1.0364489555358887
# Iteration: 28, Training loss: 1.0181235074996948
# Iteration: 29, Training loss: 1.0145810842514038
# Iteration: 30, Training loss: 1.00163996219635
# Iteration: 31, Training loss: 0.9834467172622681
# Iteration: 32, Training loss: 0.9822598099708557
# Iteration: 33, Training loss: 0.9822286367416382
# Iteration: 34, Training loss: 0.9612141847610474
# Iteration: 35, Training loss: 0.9428145885467529
# Iteration: 36, Training loss: 0.931617796421051
# Iteration: 37, Training loss: 0.922757089138031
# Iteration: 38, Training loss: 0.9150687456130981
# Iteration: 39, Training loss: 0.9097470641136169
# Iteration: 40, Training loss: 0.8960764408111572
# Iteration: 41, Training loss: 0.8963977098464966
# Iteration: 42, Training loss: 0.9057331681251526
# Iteration: 43, Training loss: 0.8690357804298401
# Iteration: 44, Training loss: 0.8583294153213501
# Iteration: 45, Training loss: 0.8479777574539185
# Iteration: 46, Training loss: 0.848361074924469
# Iteration: 47, Training loss: 0.8381544947624207
# Iteration: 48, Training loss: 0.8232394456863403
# Iteration: 49, Training loss: 0.8254813551902771
# Iteration: 50, Training loss: 0.798730194568634
# Iteration: 51, Training loss: 0.8048310875892639
# Iteration: 52, Training loss: 0.7870096564292908
# Iteration: 53, Training loss: 0.7870418429374695
# Iteration: 54, Training loss: 0.7695705890655518
# Iteration: 55, Training loss: 0.7644639611244202
# Iteration: 56, Training loss: 0.7523742914199829
# Iteration: 57, Training loss: 0.7442917823791504
# Iteration: 58, Training loss: 0.722594141960144
# Iteration: 59, Training loss: 0.7261425256729126
# Iteration: 60, Training loss: 0.7107254862785339
# Iteration: 61, Training loss: 0.701241135597229
# Iteration: 62, Training loss: 0.6920000314712524
# Iteration: 63, Training loss: 0.6882805228233337
# Iteration: 64, Training loss: 0.6694621443748474
# Iteration: 65, Training loss: 0.6663315296173096
# Iteration: 66, Training loss: 0.6508160829544067
# Iteration: 67, Training loss: 0.6605345606803894
# Iteration: 68, Training loss: 0.6393113136291504
# Iteration: 69, Training loss: 0.6296421885490417
# Iteration: 70, Training loss: 0.6199136972427368
# Iteration: 71, Training loss: 0.6120338439941406
# Iteration: 72, Training loss: 0.6093926429748535
# Iteration: 73, Training loss: 0.6086505651473999
# Iteration: 74, Training loss: 0.5927972793579102
# Iteration: 75, Training loss: 0.5893745422363281
# Iteration: 76, Training loss: 0.5816388726234436
# Iteration: 77, Training loss: 0.5737653970718384
# Iteration: 78, Training loss: 0.5663332939147949
# Iteration: 79, Training loss: 0.5663442611694336
# Iteration: 80, Training loss: 0.5509098172187805
# Iteration: 81, Training loss: 0.5391876697540283
# Iteration: 82, Training loss: 0.5361731648445129
# Iteration: 83, Training loss: 0.5247484445571899
# Iteration: 84, Training loss: 0.5225452780723572
# Iteration: 85, Training loss: 0.5191246271133423
# Iteration: 86, Training loss: 0.49743372201919556
# Iteration: 87, Training loss: 0.498418927192688
# Iteration: 88, Training loss: 0.48677265644073486
# Iteration: 89, Training loss: 0.49936777353286743
# Iteration: 90, Training loss: 0.4816320538520813
# Iteration: 91, Training loss: 0.4733419120311737
# Iteration: 92, Training loss: 0.46616774797439575
# Iteration: 93, Training loss: 0.4539893567562103
# Iteration: 94, Training loss: 0.4506649076938629
# Iteration: 95, Training loss: 0.44298020005226135
# Iteration: 96, Training loss: 0.448748379945755
# Iteration: 97, Training loss: 0.4228455126285553
# Iteration: 98, Training loss: 0.4561935365200043
# Iteration: 99, Training loss: 0.41659054160118103
# Iteration: 100, Training loss: 0.41967031359672546
# Iteration: 100, Test loss: 0.4391060769557953
# Iteration: 101, Training loss: 0.4192672669887543
# Iteration: 102, Training loss: 0.4142284095287323
# Iteration: 103, Training loss: 0.40081363916397095
# Iteration: 104, Training loss: 0.3977689743041992
# Iteration: 105, Training loss: 0.3948907256126404
# Iteration: 106, Training loss: 0.38658612966537476
# Iteration: 107, Training loss: 0.3786452114582062
# Iteration: 108, Training loss: 0.37011268734931946
# Iteration: 109, Training loss: 0.3749784231185913
# Iteration: 110, Training loss: 0.37521305680274963
# Iteration: 111, Training loss: 0.36234650015830994
# Iteration: 112, Training loss: 0.3511762022972107
# Iteration: 113, Training loss: 0.34819257259368896
# Iteration: 114, Training loss: 0.3643118143081665
# Iteration: 115, Training loss: 0.357500821352005
# Iteration: 116, Training loss: 0.35400763154029846
# Iteration: 117, Training loss: 0.32012689113616943
# Iteration: 118, Training loss: 0.32138770818710327
# Iteration: 119, Training loss: 0.32712700963020325
# Iteration: 120, Training loss: 0.3258160650730133
# Iteration: 121, Training loss: 0.31353259086608887
# Iteration: 122, Training loss: 0.3206564784049988
# Iteration: 123, Training loss: 0.3184497058391571
# Iteration: 124, Training loss: 0.3141342103481293
# Iteration: 125, Training loss: 0.3060804009437561
# Iteration: 126, Training loss: 0.2993870973587036
# Iteration: 127, Training loss: 0.2856745421886444
# Iteration: 128, Training loss: 0.29323217272758484
# Iteration: 129, Training loss: 0.2906930148601532
# Iteration: 130, Training loss: 0.2951602041721344
# Iteration: 131, Training loss: 0.27090734243392944
# Iteration: 132, Training loss: 0.28588926792144775
# Iteration: 133, Training loss: 0.27450916171073914
# Iteration: 134, Training loss: 0.29000014066696167
# Iteration: 135, Training loss: 0.2719292640686035
# Iteration: 136, Training loss: 0.27133843302726746
# Iteration: 137, Training loss: 0.2669517397880554
# Iteration: 138, Training loss: 0.2549635171890259
# Iteration: 139, Training loss: 0.2500488758087158
# Iteration: 140, Training loss: 0.25382769107818604
# Iteration: 141, Training loss: 0.2528662085533142
# Iteration: 142, Training loss: 0.24378527700901031
# Iteration: 143, Training loss: 0.24745191633701324
# Iteration: 144, Training loss: 0.24728672206401825
# Iteration: 145, Training loss: 0.2440558671951294
# Iteration: 146, Training loss: 0.22196665406227112
# Iteration: 147, Training loss: 0.23624835908412933
# Iteration: 148, Training loss: 0.24009138345718384
# Iteration: 149, Training loss: 0.2339327335357666
# Iteration: 150, Training loss: 0.25388020277023315
# Iteration: 151, Training loss: 0.23924599587917328
# Iteration: 152, Training loss: 0.2151586413383484
# Iteration: 153, Training loss: 0.23375292122364044
# Iteration: 154, Training loss: 0.24054835736751556
# Iteration: 155, Training loss: 0.21947592496871948
# Iteration: 156, Training loss: 0.20313633978366852
# Iteration: 157, Training loss: 0.20838777720928192
# Iteration: 158, Training loss: 0.2182265669107437
# Iteration: 159, Training loss: 0.20112644135951996
# Iteration: 160, Training loss: 0.21202301979064941
# Iteration: 161, Training loss: 0.20609994232654572
# Iteration: 162, Training loss: 0.20753376185894012
# Iteration: 163, Training loss: 0.19892607629299164
# Iteration: 164, Training loss: 0.18963730335235596
# Iteration: 165, Training loss: 0.21100151538848877
# Iteration: 166, Training loss: 0.2144732028245926
# Iteration: 167, Training loss: 0.18981535732746124
# Iteration: 168, Training loss: 0.2101893126964569
# Iteration: 169, Training loss: 0.17966881394386292
# Iteration: 170, Training loss: 0.1790909767150879
# Iteration: 171, Training loss: 0.1817002147436142
# Iteration: 172, Training loss: 0.19359168410301208
# Iteration: 173, Training loss: 0.18795759975910187
# Iteration: 174, Training loss: 0.17083141207695007
# Iteration: 175, Training loss: 0.18486587703227997
# Iteration: 176, Training loss: 0.20821483433246613
# Iteration: 177, Training loss: 0.18302395939826965
# Iteration: 178, Training loss: 0.18009571731090546
# Iteration: 179, Training loss: 0.18909339606761932
# Iteration: 180, Training loss: 0.17583423852920532
# Iteration: 181, Training loss: 0.17346757650375366
# Iteration: 182, Training loss: 0.17958606779575348
# Iteration: 183, Training loss: 0.1774957925081253
# Iteration: 184, Training loss: 0.15860670804977417
# Iteration: 185, Training loss: 0.1754211038351059
# Iteration: 186, Training loss: 0.16523832082748413
# Iteration: 187, Training loss: 0.18561196327209473
# Iteration: 188, Training loss: 0.18447774648666382
# Iteration: 189, Training loss: 0.16746778786182404
# Iteration: 190, Training loss: 0.15271614491939545
# Iteration: 191, Training loss: 0.14390695095062256
# Iteration: 192, Training loss: 0.16830120980739594
# Iteration: 193, Training loss: 0.17090672254562378
# Iteration: 194, Training loss: 0.16292919218540192
# Iteration: 195, Training loss: 0.16772490739822388
# Iteration: 196, Training loss: 0.1613161563873291
# Iteration: 197, Training loss: 0.14382149279117584
# Iteration: 198, Training loss: 0.16435660421848297
# Iteration: 199, Training loss: 0.1687915325164795
# Iteration: 200, Training loss: 0.15965688228607178
# Iteration: 200, Test loss: 0.1589585542678833
# Iteration: 201, Training loss: 0.1436072736978531
# Iteration: 202, Training loss: 0.172067791223526
# Iteration: 203, Training loss: 0.16161054372787476
# Iteration: 204, Training loss: 0.1526201218366623
# Iteration: 205, Training loss: 0.15987157821655273
# Iteration: 206, Training loss: 0.1385670155286789
# Iteration: 207, Training loss: 0.1492474377155304
# Iteration: 208, Training loss: 0.14232218265533447
# Iteration: 209, Training loss: 0.15263362228870392
# Iteration: 210, Training loss: 0.13241857290267944
# Iteration: 211, Training loss: 0.15402086079120636
# Iteration: 212, Training loss: 0.1445910781621933
# Iteration: 213, Training loss: 0.13644391298294067
# Iteration: 214, Training loss: 0.13845263421535492
# Iteration: 215, Training loss: 0.1485411375761032
# Iteration: 216, Training loss: 0.13855618238449097
# Iteration: 217, Training loss: 0.1262626051902771
# Iteration: 218, Training loss: 0.1424398571252823
# Iteration: 219, Training loss: 0.13408957421779633
# Iteration: 220, Training loss: 0.13341957330703735
# Iteration: 221, Training loss: 0.130992591381073
# Iteration: 222, Training loss: 0.1592746078968048
# Iteration: 223, Training loss: 0.1374247521162033
# Iteration: 224, Training loss: 0.14083696901798248
# Iteration: 225, Training loss: 0.12621000409126282
# Iteration: 226, Training loss: 0.12185515463352203
# Iteration: 227, Training loss: 0.14770877361297607
# Iteration: 228, Training loss: 0.11360982805490494
# Iteration: 229, Training loss: 0.12152787297964096
# Iteration: 230, Training loss: 0.12217670679092407
# Iteration: 231, Training loss: 0.1396128535270691
# Iteration: 232, Training loss: 0.12326733767986298
# Iteration: 233, Training loss: 0.12067192047834396
# Iteration: 234, Training loss: 0.11977817863225937
# Iteration: 235, Training loss: 0.13828891515731812
# Iteration: 236, Training loss: 0.11768755316734314
# Iteration: 237, Training loss: 0.13530859351158142
# Iteration: 238, Training loss: 0.1045629009604454
# Iteration: 239, Training loss: 0.10898622870445251
# Iteration: 240, Training loss: 0.12406699359416962
# Iteration: 241, Training loss: 0.12770012021064758
# Iteration: 242, Training loss: 0.11694188416004181
# Iteration: 243, Training loss: 0.13031654059886932
# Iteration: 244, Training loss: 0.10106935352087021
# Iteration: 245, Training loss: 0.11636286228895187
# Iteration: 246, Training loss: 0.11283266544342041
# Iteration: 247, Training loss: 0.11154767870903015
# Iteration: 248, Training loss: 0.1270865797996521
# Iteration: 249, Training loss: 0.11598480492830276
# Iteration: 250, Training loss: 0.12898831069469452
# Iteration: 251, Training loss: 0.16211733222007751
# Iteration: 252, Training loss: 0.1274271458387375
# Iteration: 253, Training loss: 0.13098672032356262
# Iteration: 254, Training loss: 0.11708024889230728
# Iteration: 255, Training loss: 0.12304506450891495
# Iteration: 256, Training loss: 0.12501643598079681
# Iteration: 257, Training loss: 0.11338161677122116
# Iteration: 258, Training loss: 0.10545330494642258
# Iteration: 259, Training loss: 0.11244998872280121
# Iteration: 260, Training loss: 0.10857192426919937
# Iteration: 261, Training loss: 0.09965404123067856
# Iteration: 262, Training loss: 0.10189595818519592
# Iteration: 263, Training loss: 0.10129693150520325
# Iteration: 264, Training loss: 0.10433785617351532
# Iteration: 265, Training loss: 0.08784373849630356
# Iteration: 266, Training loss: 0.11855576932430267
# Iteration: 267, Training loss: 0.11268972605466843
# Iteration: 268, Training loss: 0.12157168239355087
# Iteration: 269, Training loss: 0.10976975411176682
# Iteration: 270, Training loss: 0.10586357116699219
# Iteration: 271, Training loss: 0.10591790825128555
# Iteration: 272, Training loss: 0.10752850025892258
# Iteration: 273, Training loss: 0.1093299463391304
# Iteration: 274, Training loss: 0.10791585594415665
# Iteration: 275, Training loss: 0.10440296679735184
# Iteration: 276, Training loss: 0.09846377372741699
# Iteration: 277, Training loss: 0.10530828684568405
# Iteration: 278, Training loss: 0.09810789674520493
# Iteration: 279, Training loss: 0.11514472961425781
# Iteration: 280, Training loss: 0.1187596544623375
# Iteration: 281, Training loss: 0.10855629295110703
# Iteration: 282, Training loss: 0.08818373084068298
# Iteration: 283, Training loss: 0.08937307447195053
# Iteration: 284, Training loss: 0.09715552628040314
# Iteration: 285, Training loss: 0.09281299263238907
# Iteration: 286, Training loss: 0.09194935113191605
# Iteration: 287, Training loss: 0.09100425988435745
# Iteration: 288, Training loss: 0.10789614170789719
# Iteration: 289, Training loss: 0.11124614626169205
# Iteration: 290, Training loss: 0.09958357363939285
# Iteration: 291, Training loss: 0.0850609838962555
# Iteration: 292, Training loss: 0.10557999461889267
# Iteration: 293, Training loss: 0.09196431189775467
# Iteration: 294, Training loss: 0.09820105880498886
# Iteration: 295, Training loss: 0.08120665699243546
# Iteration: 296, Training loss: 0.09720201790332794
# Iteration: 297, Training loss: 0.09033370763063431
# Iteration: 298, Training loss: 0.09374276548624039
# Iteration: 299, Training loss: 0.08493740856647491
# Iteration: 300, Training loss: 0.09272050857543945
# Iteration: 300, Test loss: 0.14131857454776764
# Iteration: 301, Training loss: 0.08607538044452667
# Iteration: 302, Training loss: 0.09488169103860855
# Iteration: 303, Training loss: 0.10104739665985107
# Iteration: 304, Training loss: 0.09111537784337997
# Iteration: 305, Training loss: 0.11443132907152176
# Iteration: 306, Training loss: 0.10968382656574249
# Iteration: 307, Training loss: 0.08775798231363297
# Iteration: 308, Training loss: 0.08013764768838882
# Iteration: 309, Training loss: 0.10378558188676834
# Iteration: 310, Training loss: 0.11375390738248825
# Iteration: 311, Training loss: 0.08912926912307739
# Iteration: 312, Training loss: 0.09407821297645569
# Iteration: 313, Training loss: 0.10246974229812622
# Iteration: 314, Training loss: 0.09723988175392151
# Iteration: 315, Training loss: 0.08689268678426743
# Iteration: 316, Training loss: 0.07784510403871536
# Iteration: 317, Training loss: 0.06598047912120819
# Iteration: 318, Training loss: 0.07291457056999207
# Iteration: 319, Training loss: 0.09417496621608734
# Iteration: 320, Training loss: 0.07991600036621094
# Iteration: 321, Training loss: 0.0782955139875412
# Iteration: 322, Training loss: 0.10850978642702103
# Iteration: 323, Training loss: 0.08270922303199768
# Iteration: 324, Training loss: 0.08316302299499512
# Iteration: 325, Training loss: 0.07361744344234467
# Iteration: 326, Training loss: 0.08934172987937927
# Iteration: 327, Training loss: 0.07767798751592636
# Iteration: 328, Training loss: 0.08882290124893188
# Iteration: 329, Training loss: 0.08633296191692352
# Iteration: 330, Training loss: 0.08276958763599396
# Iteration: 331, Training loss: 0.07894778996706009
# Iteration: 332, Training loss: 0.0836493968963623
# Iteration: 333, Training loss: 0.07773914933204651
# Iteration: 334, Training loss: 0.08145562559366226
# Iteration: 335, Training loss: 0.08517985790967941
# Iteration: 336, Training loss: 0.07559985667467117
# Iteration: 337, Training loss: 0.11930090188980103
# Iteration: 338, Training loss: 0.09430821985006332
# Iteration: 339, Training loss: 0.10389453172683716
# Iteration: 340, Training loss: 0.11240585893392563
# Iteration: 341, Training loss: 0.09895434230566025
# Iteration: 342, Training loss: 0.08886101841926575
# Iteration: 343, Training loss: 0.08010576665401459
# Iteration: 344, Training loss: 0.08493839204311371
# Iteration: 345, Training loss: 0.0774412676692009
# Iteration: 346, Training loss: 0.07830402255058289
# Iteration: 347, Training loss: 0.09979278594255447
# Iteration: 348, Training loss: 0.07768921554088593
# Iteration: 349, Training loss: 0.09289167076349258
# Iteration: 350, Training loss: 0.10438821464776993
# Iteration: 351, Training loss: 0.06922196596860886
# Iteration: 352, Training loss: 0.07711818069219589
# Iteration: 353, Training loss: 0.0792786255478859
# Iteration: 354, Training loss: 0.08011633902788162
# Iteration: 355, Training loss: 0.07068990170955658
# Iteration: 356, Training loss: 0.06926271319389343
# Iteration: 357, Training loss: 0.08392351865768433
# Iteration: 358, Training loss: 0.07458759844303131
# Iteration: 359, Training loss: 0.08321040123701096
# Iteration: 360, Training loss: 0.07313907146453857
# Iteration: 361, Training loss: 0.094319187104702
# Iteration: 362, Training loss: 0.05550839751958847
# Iteration: 363, Training loss: 0.08103557676076889
# Iteration: 364, Training loss: 0.08132260292768478
# Iteration: 365, Training loss: 0.07757095992565155
# Iteration: 366, Training loss: 0.06767603754997253
# Iteration: 367, Training loss: 0.10402864217758179
# Iteration: 368, Training loss: 0.08084463328123093
# Iteration: 369, Training loss: 0.0875331312417984
# Iteration: 370, Training loss: 0.06493320316076279
# Iteration: 371, Training loss: 0.09395778924226761
# Iteration: 372, Training loss: 0.08525730669498444
# Iteration: 373, Training loss: 0.07020340114831924
# Iteration: 374, Training loss: 0.09021284431219101
# Iteration: 375, Training loss: 0.06859166920185089
# Iteration: 376, Training loss: 0.07984346151351929
# Iteration: 377, Training loss: 0.09918109327554703
# Iteration: 378, Training loss: 0.09159719198942184
# Iteration: 379, Training loss: 0.06684775650501251
# Iteration: 380, Training loss: 0.085136778652668
# Iteration: 381, Training loss: 0.08971903473138809
# Iteration: 382, Training loss: 0.08335262537002563
# Iteration: 383, Training loss: 0.0785212516784668
# Iteration: 384, Training loss: 0.07544192671775818
# Iteration: 385, Training loss: 0.08813595026731491
# Iteration: 386, Training loss: 0.06298699975013733
# Iteration: 387, Training loss: 0.06546686589717865
# Iteration: 388, Training loss: 0.09152835607528687
# Iteration: 389, Training loss: 0.08358697593212128
# Iteration: 390, Training loss: 0.08477654308080673
# Iteration: 391, Training loss: 0.08709574490785599
# Iteration: 392, Training loss: 0.08658533543348312
# Iteration: 393, Training loss: 0.08133131265640259
# Iteration: 394, Training loss: 0.07472635805606842
# Iteration: 395, Training loss: 0.07396802306175232
# Iteration: 396, Training loss: 0.08374952524900436
# Iteration: 397, Training loss: 0.07145630568265915
# Iteration: 398, Training loss: 0.0676099881529808
# Iteration: 399, Training loss: 0.08515826612710953
# Iteration: 400, Training loss: 0.06254418194293976
# Iteration: 400, Test loss: 0.11443008482456207
# Iteration: 401, Training loss: 0.09101247042417526
# Iteration: 402, Training loss: 0.06644735485315323
# Iteration: 403, Training loss: 0.07010643184185028
# Iteration: 404, Training loss: 0.06060201674699783
# Iteration: 405, Training loss: 0.07485000789165497
# Iteration: 406, Training loss: 0.067476287484169
# Iteration: 407, Training loss: 0.09248873591423035
# Iteration: 408, Training loss: 0.06333288550376892
# Iteration: 409, Training loss: 0.07102037966251373
# Iteration: 410, Training loss: 0.08831943571567535
# Iteration: 411, Training loss: 0.06765275448560715
# Iteration: 412, Training loss: 0.07190907746553421
# Iteration: 413, Training loss: 0.08521746098995209
# Iteration: 414, Training loss: 0.08618927747011185
# Iteration: 415, Training loss: 0.07392573356628418
# Iteration: 416, Training loss: 0.08965235948562622
# Iteration: 417, Training loss: 0.06597036868333817
# Iteration: 418, Training loss: 0.07310348004102707
# Iteration: 419, Training loss: 0.06122226268053055
# Iteration: 420, Training loss: 0.08329430222511292
# Iteration: 421, Training loss: 0.053688324987888336
# Iteration: 422, Training loss: 0.05025221407413483
# Iteration: 423, Training loss: 0.08242147415876389
# Iteration: 424, Training loss: 0.06570389866828918
# Iteration: 425, Training loss: 0.07149110734462738
# Iteration: 426, Training loss: 0.07412570714950562
# Iteration: 427, Training loss: 0.05710434541106224
# Iteration: 428, Training loss: 0.07450587302446365
# Iteration: 429, Training loss: 0.055882830172777176
# Iteration: 430, Training loss: 0.08323031663894653
# Iteration: 431, Training loss: 0.06890104711055756
# Iteration: 432, Training loss: 0.06803154200315475
# Iteration: 433, Training loss: 0.060173552483320236
# Iteration: 434, Training loss: 0.06380564719438553
# Iteration: 435, Training loss: 0.0746694952249527
# Iteration: 436, Training loss: 0.0692915990948677
# Iteration: 437, Training loss: 0.08290347456932068
# Iteration: 438, Training loss: 0.07582277804613113
# Iteration: 439, Training loss: 0.060461387038230896
# Iteration: 440, Training loss: 0.05684157460927963
# Iteration: 441, Training loss: 0.07538623362779617
# Iteration: 442, Training loss: 0.06516175717115402
# Iteration: 443, Training loss: 0.06305057555437088
# Iteration: 444, Training loss: 0.06853778660297394
# Iteration: 445, Training loss: 0.04048151150345802
# Iteration: 446, Training loss: 0.06453197449445724
# Iteration: 447, Training loss: 0.06694874912500381
# Iteration: 448, Training loss: 0.05937488004565239
# Iteration: 449, Training loss: 0.05940898507833481
# Iteration: 450, Training loss: 0.07027780264616013
# Iteration: 451, Training loss: 0.05155698582530022
# Iteration: 452, Training loss: 0.07039076089859009
# Iteration: 453, Training loss: 0.07879646122455597
# Iteration: 454, Training loss: 0.06302645802497864
# Iteration: 455, Training loss: 0.08347143977880478
# Iteration: 456, Training loss: 0.06011757627129555
# Iteration: 457, Training loss: 0.07938132435083389
# Iteration: 458, Training loss: 0.06340686976909637
# Iteration: 459, Training loss: 0.06809450685977936
# Iteration: 460, Training loss: 0.0764349177479744
# Iteration: 461, Training loss: 0.05366843193769455
# Iteration: 462, Training loss: 0.08677275478839874
# Iteration: 463, Training loss: 0.06296378374099731
# Iteration: 464, Training loss: 0.06379161775112152
# Iteration: 465, Training loss: 0.062020283192396164
# Iteration: 466, Training loss: 0.06895618885755539
# Iteration: 467, Training loss: 0.05549388751387596
# Iteration: 468, Training loss: 0.08793412148952484
# Iteration: 469, Training loss: 0.060147181153297424
# Iteration: 470, Training loss: 0.07710886746644974
# Iteration: 471, Training loss: 0.07542150467634201
# Iteration: 472, Training loss: 0.06718653440475464
# Iteration: 473, Training loss: 0.08058948069810867
# Iteration: 474, Training loss: 0.05011211335659027
# Iteration: 475, Training loss: 0.060446616262197495
# Iteration: 476, Training loss: 0.0513632632791996
# Iteration: 477, Training loss: 0.04494151473045349
# Iteration: 478, Training loss: 0.0546216256916523
# Iteration: 479, Training loss: 0.06440717726945877
# Iteration: 480, Training loss: 0.0711018294095993
# Iteration: 481, Training loss: 0.05938481539487839
# Iteration: 482, Training loss: 0.07793404161930084
# Iteration: 483, Training loss: 0.07133423537015915
# Iteration: 484, Training loss: 0.07461880892515182
# Iteration: 485, Training loss: 0.07935699820518494
# Iteration: 486, Training loss: 0.064836286008358
# Iteration: 487, Training loss: 0.058233488351106644
# Iteration: 488, Training loss: 0.0545194037258625
# Iteration: 489, Training loss: 0.05147818103432655
# Iteration: 490, Training loss: 0.055485084652900696
# Iteration: 491, Training loss: 0.07305879890918732
# Iteration: 492, Training loss: 0.05211291462182999
# Iteration: 493, Training loss: 0.09294842928647995
# Iteration: 494, Training loss: 0.07353454828262329
# Iteration: 495, Training loss: 0.057109568268060684
# Iteration: 496, Training loss: 0.04021165519952774
# Iteration: 497, Training loss: 0.06286177784204483
# Iteration: 498, Training loss: 0.07124640047550201
# Iteration: 499, Training loss: 0.06539111584424973
# Iteration: 500, Training loss: 0.04467737302184105
# Iteration: 500, Test loss: 0.11601091176271439
# Iteration: 501, Training loss: 0.06969931721687317
# Iteration: 502, Training loss: 0.06613504141569138
# Iteration: 503, Training loss: 0.06753603368997574
# Iteration: 504, Training loss: 0.06703601777553558
# Iteration: 505, Training loss: 0.06014076992869377
# Iteration: 506, Training loss: 0.07684207707643509
# Iteration: 507, Training loss: 0.06721356511116028
# Iteration: 508, Training loss: 0.06041700020432472
# Iteration: 509, Training loss: 0.06023647263646126
# Iteration: 510, Training loss: 0.06011323630809784
# Iteration: 511, Training loss: 0.07969904690980911
# Iteration: 512, Training loss: 0.06769619137048721
# Iteration: 513, Training loss: 0.041622892022132874
# Iteration: 514, Training loss: 0.08237114548683167
# Iteration: 515, Training loss: 0.0505535788834095
# Iteration: 516, Training loss: 0.06452076882123947
# Iteration: 517, Training loss: 0.06011251360177994
# Iteration: 518, Training loss: 0.06469118595123291
# Iteration: 519, Training loss: 0.05899988114833832
# Iteration: 520, Training loss: 0.05809672176837921
# Iteration: 521, Training loss: 0.055175330489873886
# Iteration: 522, Training loss: 0.06620810925960541
# Iteration: 523, Training loss: 0.07750196009874344
# Iteration: 524, Training loss: 0.06758037209510803
# Iteration: 525, Training loss: 0.06961512565612793
# Iteration: 526, Training loss: 0.05812409892678261
# Iteration: 527, Training loss: 0.06838364154100418
# Iteration: 528, Training loss: 0.08128119260072708
# Iteration: 529, Training loss: 0.051056869328022
# Iteration: 530, Training loss: 0.08642303198575974
# Iteration: 531, Training loss: 0.06448093801736832
# Iteration: 532, Training loss: 0.066255584359169
# Iteration: 533, Training loss: 0.06226211041212082
# Iteration: 534, Training loss: 0.05888611078262329
# Iteration: 535, Training loss: 0.0634533241391182
# Iteration: 536, Training loss: 0.06752656400203705
# Iteration: 537, Training loss: 0.07049291580915451
# Iteration: 538, Training loss: 0.04821404442191124
# Iteration: 539, Training loss: 0.07471458613872528
# Iteration: 540, Training loss: 0.06808041781187057
# Iteration: 541, Training loss: 0.06472761929035187
# Iteration: 542, Training loss: 0.047214481979608536
# Iteration: 543, Training loss: 0.049349959939718246
# Iteration: 544, Training loss: 0.08992669731378555
# Iteration: 545, Training loss: 0.04956319183111191
# Iteration: 546, Training loss: 0.04014287889003754
# Iteration: 547, Training loss: 0.050622981041669846
# Iteration: 548, Training loss: 0.05868351459503174
# Iteration: 549, Training loss: 0.0660834088921547
# Iteration: 550, Training loss: 0.040568526834249496
# Iteration: 551, Training loss: 0.07662229239940643
# Iteration: 552, Training loss: 0.06194842606782913
# Iteration: 553, Training loss: 0.08056941628456116
# Iteration: 554, Training loss: 0.05512557551264763
# Iteration: 555, Training loss: 0.0741322934627533
# Iteration: 556, Training loss: 0.06708663702011108
# Iteration: 557, Training loss: 0.057622410356998444
# Iteration: 558, Training loss: 0.08041804283857346
# Iteration: 559, Training loss: 0.06929367780685425
# Iteration: 560, Training loss: 0.07792724668979645
# Iteration: 561, Training loss: 0.0680810734629631
# Iteration: 562, Training loss: 0.05117997154593468
# Iteration: 563, Training loss: 0.06747713685035706
# Iteration: 564, Training loss: 0.08057913929224014
# Iteration: 565, Training loss: 0.038451895117759705
# Iteration: 566, Training loss: 0.04160069674253464
# Iteration: 567, Training loss: 0.060217346996068954
# Iteration: 568, Training loss: 0.03959310054779053
# Iteration: 569, Training loss: 0.06759462505578995
# Iteration: 570, Training loss: 0.05288097262382507
# Iteration: 571, Training loss: 0.07214032858610153
# Iteration: 572, Training loss: 0.06039229780435562
# Iteration: 573, Training loss: 0.06104755401611328
# Iteration: 574, Training loss: 0.08019194006919861
# Iteration: 575, Training loss: 0.06822451949119568
# Iteration: 576, Training loss: 0.06452733278274536
# Iteration: 577, Training loss: 0.0564914233982563
# Iteration: 578, Training loss: 0.06214871257543564
# Iteration: 579, Training loss: 0.0679219663143158
# Iteration: 580, Training loss: 0.0557718463242054
# Iteration: 581, Training loss: 0.0522194430232048
# Iteration: 582, Training loss: 0.060954153537750244
# Iteration: 583, Training loss: 0.05977696180343628
# Iteration: 584, Training loss: 0.056391067802906036
# Iteration: 585, Training loss: 0.0562388114631176
# Iteration: 586, Training loss: 0.06782162189483643
# Iteration: 587, Training loss: 0.06447318196296692
# Iteration: 588, Training loss: 0.061002325266599655
# Iteration: 589, Training loss: 0.0486052967607975
# Iteration: 590, Training loss: 0.08362581580877304
# Iteration: 591, Training loss: 0.05956282839179039
# Iteration: 592, Training loss: 0.07463036477565765
# Iteration: 593, Training loss: 0.06311946362257004
# Iteration: 594, Training loss: 0.0570828802883625
# Iteration: 595, Training loss: 0.07495996356010437
# Iteration: 596, Training loss: 0.05877241492271423
# Iteration: 597, Training loss: 0.06406236439943314
# Iteration: 598, Training loss: 0.06727349013090134
# Iteration: 599, Training loss: 0.05208814516663551
# Iteration: 600, Training loss: 0.06366836279630661
# Iteration: 600, Test loss: 0.05268675461411476
# Iteration: 601, Training loss: 0.06831631809473038
# Iteration: 602, Training loss: 0.04085278511047363
# Iteration: 603, Training loss: 0.05318710207939148
# Iteration: 604, Training loss: 0.05089934915304184
# Iteration: 605, Training loss: 0.06316418945789337
# Iteration: 606, Training loss: 0.05757875740528107
# Iteration: 607, Training loss: 0.05182446911931038
# Iteration: 608, Training loss: 0.04665475711226463
# Iteration: 609, Training loss: 0.07385746389627457
# Iteration: 610, Training loss: 0.047936275601387024
# Iteration: 611, Training loss: 0.06292596459388733
# Iteration: 612, Training loss: 0.05853830277919769
# Iteration: 613, Training loss: 0.044925507158041
# Iteration: 614, Training loss: 0.05136234685778618
# Iteration: 615, Training loss: 0.047430600970983505
# Iteration: 616, Training loss: 0.04729679971933365
# Iteration: 617, Training loss: 0.047305867075920105
# Iteration: 618, Training loss: 0.07330705225467682
# Iteration: 619, Training loss: 0.05276533216238022
# Iteration: 620, Training loss: 0.061347562819719315
# Iteration: 621, Training loss: 0.06651842594146729
# Iteration: 622, Training loss: 0.07147464901208878
# Iteration: 623, Training loss: 0.05770934745669365
# Iteration: 624, Training loss: 0.06201763078570366
# Iteration: 625, Training loss: 0.08206457644701004
# Iteration: 626, Training loss: 0.06278692185878754
# Iteration: 627, Training loss: 0.04899509996175766
# Iteration: 628, Training loss: 0.04732885584235191
# Iteration: 629, Training loss: 0.06172146648168564
# Iteration: 630, Training loss: 0.04896130785346031
# Iteration: 631, Training loss: 0.04522470384836197
# Iteration: 632, Training loss: 0.05605301633477211
# Iteration: 633, Training loss: 0.052827563136816025
# Iteration: 634, Training loss: 0.052374858409166336
# Iteration: 635, Training loss: 0.058433759957551956
# Iteration: 636, Training loss: 0.05992792919278145
# Iteration: 637, Training loss: 0.047891050577163696
# Iteration: 638, Training loss: 0.07092377543449402
# Iteration: 639, Training loss: 0.04687526449561119
# Iteration: 640, Training loss: 0.04205906391143799
# Iteration: 641, Training loss: 0.07816758751869202
# Iteration: 642, Training loss: 0.05676649883389473
# Iteration: 643, Training loss: 0.06930283457040787
# Iteration: 644, Training loss: 0.04912569373846054
# Iteration: 645, Training loss: 0.06435893476009369
# Iteration: 646, Training loss: 0.05947596952319145
# Iteration: 647, Training loss: 0.0441683866083622
# Iteration: 648, Training loss: 0.06081818789243698
# Iteration: 649, Training loss: 0.07426300644874573
# Iteration: 650, Training loss: 0.045277100056409836
# Iteration: 651, Training loss: 0.06270129233598709
# Iteration: 652, Training loss: 0.08111537247896194
# Iteration: 653, Training loss: 0.04934365302324295
# Iteration: 654, Training loss: 0.04093918949365616
# Iteration: 655, Training loss: 0.0467519536614418
# Iteration: 656, Training loss: 0.050377607345581055
# Iteration: 657, Training loss: 0.0712725818157196
# Iteration: 658, Training loss: 0.050217777490615845
# Iteration: 659, Training loss: 0.05284683406352997
# Iteration: 660, Training loss: 0.06118673458695412
# Iteration: 661, Training loss: 0.04529435932636261
# Iteration: 662, Training loss: 0.03994082286953926
# Iteration: 663, Training loss: 0.04610062018036842
# Iteration: 664, Training loss: 0.06545845419168472
# Iteration: 665, Training loss: 0.05525080859661102
# Iteration: 666, Training loss: 0.03558570146560669
# Iteration: 667, Training loss: 0.043000124394893646
# Iteration: 668, Training loss: 0.030920833349227905
# Iteration: 669, Training loss: 0.04193964600563049
# Iteration: 670, Training loss: 0.05277051404118538
# Iteration: 671, Training loss: 0.09183032810688019
# Iteration: 672, Training loss: 0.05946483463048935
# Iteration: 673, Training loss: 0.03448142483830452
# Iteration: 674, Training loss: 0.05110442265868187
# Iteration: 675, Training loss: 0.05626019835472107
# Iteration: 676, Training loss: 0.06706535071134567
# Iteration: 677, Training loss: 0.08379494398832321
# Iteration: 678, Training loss: 0.04828149080276489
# Iteration: 679, Training loss: 0.07306690514087677
# Iteration: 680, Training loss: 0.04410257935523987
# Iteration: 681, Training loss: 0.044427741318941116
# Iteration: 682, Training loss: 0.05672796815633774
# Iteration: 683, Training loss: 0.053130630403757095
# Iteration: 684, Training loss: 0.052227385342121124
# Iteration: 685, Training loss: 0.052669987082481384
# Iteration: 686, Training loss: 0.0464576855301857
# Iteration: 687, Training loss: 0.046435438096523285
# Iteration: 688, Training loss: 0.05038003996014595
# Iteration: 689, Training loss: 0.04109407588839531
# Iteration: 690, Training loss: 0.06427280604839325
# Iteration: 691, Training loss: 0.05954556539654732
# Iteration: 692, Training loss: 0.04442301765084267
# Iteration: 693, Training loss: 0.05209445208311081
# Iteration: 694, Training loss: 0.05053100734949112
# Iteration: 695, Training loss: 0.0542677566409111
# Iteration: 696, Training loss: 0.061350464820861816
# Iteration: 697, Training loss: 0.04487878084182739
# Iteration: 698, Training loss: 0.06205441802740097
# Iteration: 699, Training loss: 0.059270527213811874
# Iteration: 700, Training loss: 0.05218498408794403
# Iteration: 700, Test loss: 0.05609748512506485
# Iteration: 701, Training loss: 0.05816664919257164
# Iteration: 702, Training loss: 0.056430380791425705
# Iteration: 703, Training loss: 0.0701880231499672
# Iteration: 704, Training loss: 0.04382186383008957
# Iteration: 705, Training loss: 0.05961839109659195
# Iteration: 706, Training loss: 0.04180047661066055
# Iteration: 707, Training loss: 0.043526194989681244
# Iteration: 708, Training loss: 0.05344907194375992
# Iteration: 709, Training loss: 0.04267742857336998
# Iteration: 710, Training loss: 0.07473299652338028
# Iteration: 711, Training loss: 0.042735420167446136
# Iteration: 712, Training loss: 0.056746214628219604
# Iteration: 713, Training loss: 0.04519534111022949
# Iteration: 714, Training loss: 0.05106467008590698
# Iteration: 715, Training loss: 0.05938198044896126
# Iteration: 716, Training loss: 0.04421975463628769
# Iteration: 717, Training loss: 0.05464831367135048
# Iteration: 718, Training loss: 0.061733368784189224
# Iteration: 719, Training loss: 0.06438177824020386
# Iteration: 720, Training loss: 0.07982782274484634
# Iteration: 721, Training loss: 0.06034892052412033
# Iteration: 722, Training loss: 0.05274413898587227
# Iteration: 723, Training loss: 0.04877716302871704
# Iteration: 724, Training loss: 0.05126766487956047
# Iteration: 725, Training loss: 0.057987283915281296
# Iteration: 726, Training loss: 0.06117042154073715
# Iteration: 727, Training loss: 0.05932186171412468
# Iteration: 728, Training loss: 0.0424550361931324
# Iteration: 729, Training loss: 0.040849264711141586
# Iteration: 730, Training loss: 0.07096923887729645
# Iteration: 731, Training loss: 0.06728190928697586
# Iteration: 732, Training loss: 0.06423120200634003
# Iteration: 733, Training loss: 0.03494652360677719
# Iteration: 734, Training loss: 0.06885705143213272
# Iteration: 735, Training loss: 0.04052310064435005
# Iteration: 736, Training loss: 0.06472057104110718
# Iteration: 737, Training loss: 0.052333731204271317
# Iteration: 738, Training loss: 0.054507505148649216
# Iteration: 739, Training loss: 0.06931097060441971
# Iteration: 740, Training loss: 0.045949265360832214
# Iteration: 741, Training loss: 0.043183423578739166
# Iteration: 742, Training loss: 0.05572420358657837
# Iteration: 743, Training loss: 0.046030573546886444
# Iteration: 744, Training loss: 0.05613880231976509
# Iteration: 745, Training loss: 0.029165716841816902
# Iteration: 746, Training loss: 0.06191449612379074
# Iteration: 747, Training loss: 0.03699049726128578
# Iteration: 748, Training loss: 0.068308524787426
# Iteration: 749, Training loss: 0.048249781131744385
# Iteration: 750, Training loss: 0.07939324527978897
# Iteration: 751, Training loss: 0.05594208464026451
# Iteration: 752, Training loss: 0.06939118355512619
# Iteration: 753, Training loss: 0.039118871092796326
# Iteration: 754, Training loss: 0.05338466539978981
# Iteration: 755, Training loss: 0.058698542416095734
# Iteration: 756, Training loss: 0.06092483922839165
# Iteration: 757, Training loss: 0.06602796167135239
# Iteration: 758, Training loss: 0.058012705296278
# Iteration: 759, Training loss: 0.04614735767245293
# Iteration: 760, Training loss: 0.043262045830488205
# Iteration: 761, Training loss: 0.05648857355117798
# Iteration: 762, Training loss: 0.055973369628190994
# Iteration: 763, Training loss: 0.08828122168779373
# Iteration: 764, Training loss: 0.040676698088645935
# Iteration: 765, Training loss: 0.05918210744857788
# Iteration: 766, Training loss: 0.043581537902355194
# Iteration: 767, Training loss: 0.053634241223335266
# Iteration: 768, Training loss: 0.04416465759277344
# Iteration: 769, Training loss: 0.05056236684322357
# Iteration: 770, Training loss: 0.048984743654727936
# Iteration: 771, Training loss: 0.04510515555739403
# Iteration: 772, Training loss: 0.05116790533065796
# Iteration: 773, Training loss: 0.06976715475320816
# Iteration: 774, Training loss: 0.055702220648527145
# Iteration: 775, Training loss: 0.057021670043468475
# Iteration: 776, Training loss: 0.06229564547538757
# Iteration: 777, Training loss: 0.056066885590553284
# Iteration: 778, Training loss: 0.040098294615745544
# Iteration: 779, Training loss: 0.06129824370145798
# Iteration: 780, Training loss: 0.045448027551174164
# Iteration: 781, Training loss: 0.07663904875516891
# Iteration: 782, Training loss: 0.041345298290252686
# Iteration: 783, Training loss: 0.05477055162191391
# Iteration: 784, Training loss: 0.057579223066568375
# Iteration: 785, Training loss: 0.06518009305000305
# Iteration: 786, Training loss: 0.05059872567653656
# Iteration: 787, Training loss: 0.06427467614412308
# Iteration: 788, Training loss: 0.06651086360216141
# Iteration: 789, Training loss: 0.04454393684864044
# Iteration: 790, Training loss: 0.0642806887626648
# Iteration: 791, Training loss: 0.0646655336022377
# Iteration: 792, Training loss: 0.05210474133491516
# Iteration: 793, Training loss: 0.05061781033873558
# Iteration: 794, Training loss: 0.04929468408226967
# Iteration: 795, Training loss: 0.05974089726805687
# Iteration: 796, Training loss: 0.049935001879930496
# Iteration: 797, Training loss: 0.0482368990778923
# Iteration: 798, Training loss: 0.05499080568552017
# Iteration: 799, Training loss: 0.05501016974449158
# Iteration: 800, Training loss: 0.048087552189826965
# Iteration: 800, Test loss: 0.051230739802122116
# Iteration: 801, Training loss: 0.05430624261498451
# Iteration: 802, Training loss: 0.0529254786670208
# Iteration: 803, Training loss: 0.047452349215745926
# Iteration: 804, Training loss: 0.04598008841276169
# Iteration: 805, Training loss: 0.0502643920481205
# Iteration: 806, Training loss: 0.05665194243192673
# Iteration: 807, Training loss: 0.053947750478982925
# Iteration: 808, Training loss: 0.03968530520796776
# Iteration: 809, Training loss: 0.061909765005111694
# Iteration: 810, Training loss: 0.06651142239570618
# Iteration: 811, Training loss: 0.04461492598056793
# Iteration: 812, Training loss: 0.04785624518990517
# Iteration: 813, Training loss: 0.06007575988769531
# Iteration: 814, Training loss: 0.04914235323667526
# Iteration: 815, Training loss: 0.06163768097758293
# Iteration: 816, Training loss: 0.06463411450386047
# Iteration: 817, Training loss: 0.05157032608985901
# Iteration: 818, Training loss: 0.06516186892986298
# Iteration: 819, Training loss: 0.041612595319747925
# Iteration: 820, Training loss: 0.042933255434036255
# Iteration: 821, Training loss: 0.07011270523071289
# Iteration: 822, Training loss: 0.05173230171203613
# Iteration: 823, Training loss: 0.058883655816316605
# Iteration: 824, Training loss: 0.04648131504654884
# Iteration: 825, Training loss: 0.051012974232435226
# Iteration: 826, Training loss: 0.05028821900486946
# Iteration: 827, Training loss: 0.04197614639997482
# Iteration: 828, Training loss: 0.05517411231994629
# Iteration: 829, Training loss: 0.0530184805393219
# Iteration: 830, Training loss: 0.04328833520412445
# Iteration: 831, Training loss: 0.06261630356311798
# Iteration: 832, Training loss: 0.050840482115745544
# Iteration: 833, Training loss: 0.05706363171339035
# Iteration: 834, Training loss: 0.0520269013941288
# Iteration: 835, Training loss: 0.03984933719038963
# Iteration: 836, Training loss: 0.036308713257312775
# Iteration: 837, Training loss: 0.06387748569250107
# Iteration: 838, Training loss: 0.05788012966513634
# Iteration: 839, Training loss: 0.04356531426310539
# Iteration: 840, Training loss: 0.03903587907552719
# Iteration: 841, Training loss: 0.05435166507959366
# Iteration: 842, Training loss: 0.05563703179359436
# Iteration: 843, Training loss: 0.04170261323451996
# Iteration: 844, Training loss: 0.0719200000166893
# Iteration: 845, Training loss: 0.05926753580570221
# Iteration: 846, Training loss: 0.049012232571840286
# Iteration: 847, Training loss: 0.04258542135357857
# Iteration: 848, Training loss: 0.05105471611022949
# Iteration: 849, Training loss: 0.034118980169296265
# Iteration: 850, Training loss: 0.041637908667325974
# Iteration: 851, Training loss: 0.05208226665854454
# Iteration: 852, Training loss: 0.048568230122327805
# Iteration: 853, Training loss: 0.04823105037212372
# Iteration: 854, Training loss: 0.03369801118969917
# Iteration: 855, Training loss: 0.043702833354473114
# Iteration: 856, Training loss: 0.04828955605626106
# Iteration: 857, Training loss: 0.0731382891535759
# Iteration: 858, Training loss: 0.05945766344666481
# Iteration: 859, Training loss: 0.06552986800670624
# Iteration: 860, Training loss: 0.04063287004828453
# Iteration: 861, Training loss: 0.06348313391208649
# Iteration: 862, Training loss: 0.047056667506694794
# Iteration: 863, Training loss: 0.044889047741889954
# Iteration: 864, Training loss: 0.031839072704315186
# Iteration: 865, Training loss: 0.07388117164373398
# Iteration: 866, Training loss: 0.041791271418333054
# Iteration: 867, Training loss: 0.06942050158977509
# Iteration: 868, Training loss: 0.04035385698080063
# Iteration: 869, Training loss: 0.04188995063304901
# Iteration: 870, Training loss: 0.06849078834056854
# Iteration: 871, Training loss: 0.040435824543237686
# Iteration: 872, Training loss: 0.04053271561861038
# Iteration: 873, Training loss: 0.04339166730642319
# Iteration: 874, Training loss: 0.04300517216324806
# Iteration: 875, Training loss: 0.0544155053794384
# Iteration: 876, Training loss: 0.08061417192220688
# Iteration: 877, Training loss: 0.049444038420915604
# Iteration: 878, Training loss: 0.04820386692881584
# Iteration: 879, Training loss: 0.060217611491680145
# Iteration: 880, Training loss: 0.05579674616456032
# Iteration: 881, Training loss: 0.07797593623399734
# Iteration: 882, Training loss: 0.06834600865840912
# Iteration: 883, Training loss: 0.07015586644411087
# Iteration: 884, Training loss: 0.06133720278739929
# Iteration: 885, Training loss: 0.062083132565021515
# Iteration: 886, Training loss: 0.04756200313568115
# Iteration: 887, Training loss: 0.061940088868141174
# Iteration: 888, Training loss: 0.05120973289012909
# Iteration: 889, Training loss: 0.046264808624982834
# Iteration: 890, Training loss: 0.045500498265028
# Iteration: 891, Training loss: 0.07104117423295975
# Iteration: 892, Training loss: 0.03441546484827995
# Iteration: 893, Training loss: 0.039858102798461914
# Iteration: 894, Training loss: 0.04026779904961586
# Iteration: 895, Training loss: 0.03134786710143089
# Iteration: 896, Training loss: 0.06647732853889465
# Iteration: 897, Training loss: 0.04967518523335457
# Iteration: 898, Training loss: 0.0736570805311203
# Iteration: 899, Training loss: 0.046269528567790985
# Iteration: 900, Training loss: 0.04779563844203949
# Iteration: 900, Test loss: 0.06595136970281601
# Iteration: 901, Training loss: 0.05019339919090271
# Iteration: 902, Training loss: 0.040927235037088394
# Iteration: 903, Training loss: 0.051829993724823
# Iteration: 904, Training loss: 0.03988489881157875
# Iteration: 905, Training loss: 0.061644088476896286
# Iteration: 906, Training loss: 0.04756217449903488
# Iteration: 907, Training loss: 0.06461699306964874
# Iteration: 908, Training loss: 0.03691868856549263
# Iteration: 909, Training loss: 0.04768138378858566
# Iteration: 910, Training loss: 0.044847272336483
# Iteration: 911, Training loss: 0.05801905319094658
# Iteration: 912, Training loss: 0.04266216605901718
# Iteration: 913, Training loss: 0.052617788314819336
# Iteration: 914, Training loss: 0.06282976269721985
# Iteration: 915, Training loss: 0.0576024167239666
# Iteration: 916, Training loss: 0.05035850778222084
# Iteration: 917, Training loss: 0.03272039443254471
# Iteration: 918, Training loss: 0.05257348343729973
# Iteration: 919, Training loss: 0.04419012740254402
# Iteration: 920, Training loss: 0.05220585688948631
# Iteration: 921, Training loss: 0.062404073774814606
# Iteration: 922, Training loss: 0.04013843461871147
# Iteration: 923, Training loss: 0.08395840972661972
# Iteration: 924, Training loss: 0.04202670231461525
# Iteration: 925, Training loss: 0.051236215978860855
# Iteration: 926, Training loss: 0.05034850910305977
# Iteration: 927, Training loss: 0.04963104799389839
# Iteration: 928, Training loss: 0.048112139105796814
# Iteration: 929, Training loss: 0.04316670447587967
# Iteration: 930, Training loss: 0.06118229776620865
# Iteration: 931, Training loss: 0.055113278329372406
# Iteration: 932, Training loss: 0.05824592337012291
# Iteration: 933, Training loss: 0.0438990481197834
# Iteration: 934, Training loss: 0.06819479167461395
# Iteration: 935, Training loss: 0.05121004208922386
# Iteration: 936, Training loss: 0.0326494500041008
# Iteration: 937, Training loss: 0.06429381668567657
# ...
# Iteration: 9702, Training loss: 0.008352016098797321
# Iteration: 9703, Training loss: 0.006775189191102982
# Iteration: 9704, Training loss: 0.005524905864149332
# Iteration: 9705, Training loss: 0.007417360786348581
# Iteration: 9706, Training loss: 0.008431244641542435
# Iteration: 9707, Training loss: 0.007690249010920525
# Iteration: 9708, Training loss: 0.007291468326002359
# Iteration: 9709, Training loss: 0.010117851197719574
# Iteration: 9710, Training loss: 0.006389841437339783
# Iteration: 9711, Training loss: 0.005413140170276165
# Iteration: 9712, Training loss: 0.006584701128304005
# Iteration: 9713, Training loss: 0.00685148686170578
# Iteration: 9714, Training loss: 0.004358374048024416
# Iteration: 9715, Training loss: 0.005689512938261032
# Iteration: 9716, Training loss: 0.005713352467864752
# Iteration: 9717, Training loss: 0.009806654416024685
# Iteration: 9718, Training loss: 0.008553905412554741
# Iteration: 9719, Training loss: 0.008388758637011051
# Iteration: 9720, Training loss: 0.009785154834389687
# Iteration: 9721, Training loss: 0.010047083720564842
# Iteration: 9722, Training loss: 0.00739256339147687
# Iteration: 9723, Training loss: 0.006777970585972071
# Iteration: 9724, Training loss: 0.007482448127120733
# Iteration: 9725, Training loss: 0.008819585666060448
# Iteration: 9726, Training loss: 0.006473630201071501
# Iteration: 9727, Training loss: 0.005963937845081091
# Iteration: 9728, Training loss: 0.006335103418678045
# Iteration: 9729, Training loss: 0.00653803301975131
# Iteration: 9730, Training loss: 0.0056638456881046295
# Iteration: 9731, Training loss: 0.00792735442519188
# Iteration: 9732, Training loss: 0.007824336178600788
# Iteration: 9733, Training loss: 0.005998531356453896
# Iteration: 9734, Training loss: 0.008118764497339725
# Iteration: 9735, Training loss: 0.011617467738687992
# Iteration: 9736, Training loss: 0.007579490542411804
# Iteration: 9737, Training loss: 0.006880125030875206
# Iteration: 9738, Training loss: 0.00873484741896391
# Iteration: 9739, Training loss: 0.010269690304994583
# Iteration: 9740, Training loss: 0.0090412562713027
# Iteration: 9741, Training loss: 0.005902925040572882
# Iteration: 9742, Training loss: 0.005467861890792847
# Iteration: 9743, Training loss: 0.005027784965932369
# Iteration: 9744, Training loss: 0.008018800057470798
# Iteration: 9745, Training loss: 0.010317041538655758
# Iteration: 9746, Training loss: 0.008353900164365768
# Iteration: 9747, Training loss: 0.006063826847821474
# Iteration: 9748, Training loss: 0.006903361063450575
# Iteration: 9749, Training loss: 0.007918223738670349
# Iteration: 9750, Training loss: 0.01005532592535019
# Iteration: 9751, Training loss: 0.0077402289025485516
# Iteration: 9752, Training loss: 0.005980304442346096
# Iteration: 9753, Training loss: 0.0071408310905098915
# Iteration: 9754, Training loss: 0.007945657707750797
# Iteration: 9755, Training loss: 0.008250261656939983
# Iteration: 9756, Training loss: 0.007562307640910149
# Iteration: 9757, Training loss: 0.006712359841912985
# Iteration: 9758, Training loss: 0.009095552377402782
# Iteration: 9759, Training loss: 0.006796151399612427
# Iteration: 9760, Training loss: 0.006853196769952774
# Iteration: 9761, Training loss: 0.007164612878113985
# Iteration: 9762, Training loss: 0.0060493131168186665
# Iteration: 9763, Training loss: 0.00791484210640192
# Iteration: 9764, Training loss: 0.004507284611463547
# Iteration: 9765, Training loss: 0.008474967442452908
# Iteration: 9766, Training loss: 0.007955511100590229
# Iteration: 9767, Training loss: 0.008698709309101105
# Iteration: 9768, Training loss: 0.010264053009450436
# Iteration: 9769, Training loss: 0.008197551593184471
# Iteration: 9770, Training loss: 0.012834489345550537
# Iteration: 9771, Training loss: 0.008868626318871975
# Iteration: 9772, Training loss: 0.0024499446153640747
# Iteration: 9773, Training loss: 0.0073154764249920845
# Iteration: 9774, Training loss: 0.009465918876230717
# Iteration: 9775, Training loss: 0.01081832591444254
# Iteration: 9776, Training loss: 0.005305824335664511
# Iteration: 9777, Training loss: 0.008286151103675365
# Iteration: 9778, Training loss: 0.007201201282441616
# Iteration: 9779, Training loss: 0.008315320126712322
# Iteration: 9780, Training loss: 0.007738090120255947
# Iteration: 9781, Training loss: 0.009419353678822517
# Iteration: 9782, Training loss: 0.006166831124573946
# Iteration: 9783, Training loss: 0.0041111125610768795
# Iteration: 9784, Training loss: 0.003426161129027605
# Iteration: 9785, Training loss: 0.006742250174283981
# Iteration: 9786, Training loss: 0.009553711861371994
# Iteration: 9787, Training loss: 0.004817875102162361
# Iteration: 9788, Training loss: 0.00930135976523161
# Iteration: 9789, Training loss: 0.007865038700401783
# Iteration: 9790, Training loss: 0.006494396366178989
# Iteration: 9791, Training loss: 0.007482307031750679
# Iteration: 9792, Training loss: 0.005598782561719418
# Iteration: 9793, Training loss: 0.009286987595260143
# Iteration: 9794, Training loss: 0.00875000935047865
# Iteration: 9795, Training loss: 0.009253417141735554
# Iteration: 9796, Training loss: 0.004443744197487831
# Iteration: 9797, Training loss: 0.0075662750750780106
# Iteration: 9798, Training loss: 0.004379027057439089
# Iteration: 9799, Training loss: 0.008512495085597038
# Iteration: 9800, Training loss: 0.005771368741989136
# Iteration: 9800, Test loss: 0.06157210096716881
# Iteration: 9801, Training loss: 0.006431388668715954
# Iteration: 9802, Training loss: 0.007582714781165123
# Iteration: 9803, Training loss: 0.006344576366245747
# Iteration: 9804, Training loss: 0.006126639433205128
# Iteration: 9805, Training loss: 0.009486513212323189
# Iteration: 9806, Training loss: 0.007761700544506311
# Iteration: 9807, Training loss: 0.007197519298642874
# Iteration: 9808, Training loss: 0.009043452329933643
# Iteration: 9809, Training loss: 0.008497861213982105
# Iteration: 9810, Training loss: 0.008221935480833054
# Iteration: 9811, Training loss: 0.0035403622314333916
# Iteration: 9812, Training loss: 0.006590042728930712
# Iteration: 9813, Training loss: 0.008541597053408623
# Iteration: 9814, Training loss: 0.006313201505690813
# Iteration: 9815, Training loss: 0.00967931654304266
# Iteration: 9816, Training loss: 0.006289062090218067
# Iteration: 9817, Training loss: 0.00596578000113368
# Iteration: 9818, Training loss: 0.004982613492757082
# Iteration: 9819, Training loss: 0.006868905853480101
# Iteration: 9820, Training loss: 0.008840769529342651
# Iteration: 9821, Training loss: 0.006839005742222071
# Iteration: 9822, Training loss: 0.010640745982527733
# Iteration: 9823, Training loss: 0.00952967256307602
# Iteration: 9824, Training loss: 0.007652177941054106
# Iteration: 9825, Training loss: 0.009778464213013649
# Iteration: 9826, Training loss: 0.010536784306168556
# Iteration: 9827, Training loss: 0.006296577863395214
# Iteration: 9828, Training loss: 0.00748310424387455
# Iteration: 9829, Training loss: 0.008502614684402943
# Iteration: 9830, Training loss: 0.004340901970863342
# Iteration: 9831, Training loss: 0.010119806043803692
# Iteration: 9832, Training loss: 0.005192647688090801
# Iteration: 9833, Training loss: 0.0059691197238862514
# Iteration: 9834, Training loss: 0.005451214034110308
# Iteration: 9835, Training loss: 0.010340607725083828
# Iteration: 9836, Training loss: 0.007527865003794432
# Iteration: 9837, Training loss: 0.012056348845362663
# Iteration: 9838, Training loss: 0.010209116153419018
# Iteration: 9839, Training loss: 0.006283632013946772
# Iteration: 9840, Training loss: 0.011260456405580044
# Iteration: 9841, Training loss: 0.009663603268563747
# Iteration: 9842, Training loss: 0.0062934341840445995
# Iteration: 9843, Training loss: 0.008977130055427551
# Iteration: 9844, Training loss: 0.01033878605812788
# Iteration: 9845, Training loss: 0.005705069284886122
# Iteration: 9846, Training loss: 0.00906292162835598
# Iteration: 9847, Training loss: 0.008640103973448277
# Iteration: 9848, Training loss: 0.005254895426332951
# Iteration: 9849, Training loss: 0.007404430769383907
# Iteration: 9850, Training loss: 0.006854769308120012
# Iteration: 9851, Training loss: 0.006236379500478506
# Iteration: 9852, Training loss: 0.00457785464823246
# Iteration: 9853, Training loss: 0.008060693740844727
# Iteration: 9854, Training loss: 0.008688755333423615
# Iteration: 9855, Training loss: 0.009232399985194206
# Iteration: 9856, Training loss: 0.007040238007903099
# Iteration: 9857, Training loss: 0.007048663683235645
# Iteration: 9858, Training loss: 0.008800671435892582
# Iteration: 9859, Training loss: 0.007874305360019207
# Iteration: 9860, Training loss: 0.009266839362680912
# Iteration: 9861, Training loss: 0.009633776731789112
# Iteration: 9862, Training loss: 0.005655142944306135
# Iteration: 9863, Training loss: 0.005098068621009588
# Iteration: 9864, Training loss: 0.00959616620093584
# Iteration: 9865, Training loss: 0.007468382362276316
# Iteration: 9866, Training loss: 0.008681757375597954
# Iteration: 9867, Training loss: 0.005273604299873114
# Iteration: 9868, Training loss: 0.006776433438062668
# Iteration: 9869, Training loss: 0.008108342997729778
# Iteration: 9870, Training loss: 0.008408977650105953
# Iteration: 9871, Training loss: 0.007762962020933628
# Iteration: 9872, Training loss: 0.007736475206911564
# Iteration: 9873, Training loss: 0.008883072063326836
# Iteration: 9874, Training loss: 0.009585081599652767
# Iteration: 9875, Training loss: 0.009055606089532375
# Iteration: 9876, Training loss: 0.011809267103672028
# Iteration: 9877, Training loss: 0.007907220162451267
# Iteration: 9878, Training loss: 0.005308850668370724
# Iteration: 9879, Training loss: 0.006058935541659594
# Iteration: 9880, Training loss: 0.009502919390797615
# Iteration: 9881, Training loss: 0.0078041329979896545
# Iteration: 9882, Training loss: 0.006820171605795622
# Iteration: 9883, Training loss: 0.005940154194831848
# Iteration: 9884, Training loss: 0.011712951585650444
# Iteration: 9885, Training loss: 0.007595173083245754
# Iteration: 9886, Training loss: 0.008885636925697327
# Iteration: 9887, Training loss: 0.004805052187293768
# Iteration: 9888, Training loss: 0.01108592376112938
# Iteration: 9889, Training loss: 0.009569564834237099
# Iteration: 9890, Training loss: 0.007807921152561903
# Iteration: 9891, Training loss: 0.008433344773948193
# Iteration: 9892, Training loss: 0.006444916129112244
# Iteration: 9893, Training loss: 0.006778878625482321
# Iteration: 9894, Training loss: 0.00899677723646164
# Iteration: 9895, Training loss: 0.003938164561986923
# Iteration: 9896, Training loss: 0.007720693480223417
# Iteration: 9897, Training loss: 0.004523658659309149
# Iteration: 9898, Training loss: 0.00769122876226902
# Iteration: 9899, Training loss: 0.008213357999920845
# Iteration: 9900, Training loss: 0.006332082208245993
# Iteration: 9900, Test loss: 0.057675305753946304
# Iteration: 9901, Training loss: 0.010569385252892971
# Iteration: 9902, Training loss: 0.008347674272954464
# Iteration: 9903, Training loss: 0.0043418374843895435
# Iteration: 9904, Training loss: 0.006162870209664106
# Iteration: 9905, Training loss: 0.004641716368496418
# Iteration: 9906, Training loss: 0.003890813561156392
# Iteration: 9907, Training loss: 0.00551710557192564
# Iteration: 9908, Training loss: 0.009318986907601357
# Iteration: 9909, Training loss: 0.005761679727584124
# Iteration: 9910, Training loss: 0.005409303121268749
# Iteration: 9911, Training loss: 0.005703537724912167
# Iteration: 9912, Training loss: 0.008581104688346386
# Iteration: 9913, Training loss: 0.005985989235341549
# Iteration: 9914, Training loss: 0.009932243265211582
# Iteration: 9915, Training loss: 0.010163004510104656
# Iteration: 9916, Training loss: 0.008447401225566864
# Iteration: 9917, Training loss: 0.009509067982435226
# Iteration: 9918, Training loss: 0.0097151268273592
# Iteration: 9919, Training loss: 0.009146408177912235
# Iteration: 9920, Training loss: 0.00835852324962616
# Iteration: 9921, Training loss: 0.009221648797392845
# Iteration: 9922, Training loss: 0.005765723995864391
# Iteration: 9923, Training loss: 0.008133448660373688
# Iteration: 9924, Training loss: 0.006807389669120312
# Iteration: 9925, Training loss: 0.00606553815305233
# Iteration: 9926, Training loss: 0.007649906445294619
# Iteration: 9927, Training loss: 0.006538078188896179
# Iteration: 9928, Training loss: 0.006182385142892599
# Iteration: 9929, Training loss: 0.0066820126958191395
# Iteration: 9930, Training loss: 0.005036614835262299
# Iteration: 9931, Training loss: 0.0055434731766581535
# Iteration: 9932, Training loss: 0.006126623600721359
# Iteration: 9933, Training loss: 0.004631740972399712
# Iteration: 9934, Training loss: 0.005048592574894428
# Iteration: 9935, Training loss: 0.009659664705395699
# Iteration: 9936, Training loss: 0.00861801765859127
# Iteration: 9937, Training loss: 0.008833379484713078
# Iteration: 9938, Training loss: 0.006020269822329283
# Iteration: 9939, Training loss: 0.006478908006101847
# Iteration: 9940, Training loss: 0.008742578327655792
# Iteration: 9941, Training loss: 0.007247623521834612
# Iteration: 9942, Training loss: 0.00982290506362915
# Iteration: 9943, Training loss: 0.007372630760073662
# Iteration: 9944, Training loss: 0.007429846562445164
# Iteration: 9945, Training loss: 0.008260532282292843
# Iteration: 9946, Training loss: 0.007706531323492527
# Iteration: 9947, Training loss: 0.0125464191660285
# Iteration: 9948, Training loss: 0.006204902660101652
# Iteration: 9949, Training loss: 0.004511451348662376
# Iteration: 9950, Training loss: 0.007546260487288237
# Iteration: 9951, Training loss: 0.0039037589449435472
# Iteration: 9952, Training loss: 0.007454376667737961
# Iteration: 9953, Training loss: 0.005483007989823818
# Iteration: 9954, Training loss: 0.00628235237672925
# Iteration: 9955, Training loss: 0.008295574225485325
# Iteration: 9956, Training loss: 0.007111041806638241
# Iteration: 9957, Training loss: 0.009637243114411831
# Iteration: 9958, Training loss: 0.00603753887116909
# Iteration: 9959, Training loss: 0.005076239351183176
# Iteration: 9960, Training loss: 0.007483803201466799
# Iteration: 9961, Training loss: 0.005862541496753693
# Iteration: 9962, Training loss: 0.009945721365511417
# Iteration: 9963, Training loss: 0.00821628887206316
# Iteration: 9964, Training loss: 0.008018136955797672
# Iteration: 9965, Training loss: 0.008494198322296143
# Iteration: 9966, Training loss: 0.00481716264039278
# Iteration: 9967, Training loss: 0.0057575898244977
# Iteration: 9968, Training loss: 0.008609265089035034
# Iteration: 9969, Training loss: 0.011593346484005451
# Iteration: 9970, Training loss: 0.004942648112773895
# Iteration: 9971, Training loss: 0.00783022865653038
# Iteration: 9972, Training loss: 0.009475231170654297
# Iteration: 9973, Training loss: 0.007118649315088987
# Iteration: 9974, Training loss: 0.007867522537708282
# Iteration: 9975, Training loss: 0.006834450177848339
# Iteration: 9976, Training loss: 0.0033028796315193176
# Iteration: 9977, Training loss: 0.005506387446075678
# Iteration: 9978, Training loss: 0.0086485231295228
# Iteration: 9979, Training loss: 0.010816848836839199
# Iteration: 9980, Training loss: 0.004769494757056236
# Iteration: 9981, Training loss: 0.007114253472536802
# Iteration: 9982, Training loss: 0.00580779230222106
# Iteration: 9983, Training loss: 0.013830362819135189
# Iteration: 9984, Training loss: 0.005534553900361061
# Iteration: 9985, Training loss: 0.005704888142645359
# Iteration: 9986, Training loss: 0.00766645697876811
# Iteration: 9987, Training loss: 0.007929235696792603
# Iteration: 9988, Training loss: 0.006049513816833496
# Iteration: 9989, Training loss: 0.00388608081266284
# Iteration: 9990, Training loss: 0.007317680399864912
# Iteration: 9991, Training loss: 0.008253633044660091
# Iteration: 9992, Training loss: 0.007978945039212704
# Iteration: 9993, Training loss: 0.004796289838850498
# Iteration: 9994, Training loss: 0.007435297127813101
# Iteration: 9995, Training loss: 0.006152968388050795
# Iteration: 9996, Training loss: 0.010183196514844894
# Iteration: 9997, Training loss: 0.007782076019793749
# Iteration: 9998, Training loss: 0.006140871439129114
# Iteration: 9999, Training loss: 0.010854014195501804
# Iteration: 10000, Training loss: 0.006700240075588226
# Iteration: 10000, Test loss: 0.069533571600914
# Training took 2906.647s in total.

# %% [markdown]
# ## 5. Deploy the trained model to a random set of 4 test images and visualise the automated segmentation.
#
# You can show the images as a 4 x 3 panel. Each row shows one example, with the 3 columns being the test image, automated segmentation and ground truth segmentation.

# %%
images, labels = test_set.get_random_batch(4)
images, labels = torch.from_numpy(images), torch.from_numpy(labels)
images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)

model.load_state_dict(torch.load(os.path.join(model_dir, 'model_10000.pt')))

output = model(images)

def visualise(images, labels, output):
    with torch.no_grad():
        images = torch.squeeze(images).detach()
        labels = torch.squeeze(labels).detach()
        # Need to produce a single image from output
        outputs = torch.squeeze(output).detach()
        merged_outputs = []
        for output in outputs:
            # apply thresholding so that the black one doesn't always win
            merged_outputs.append(np.argmax(output, axis = 0))
            
        figure = plt.figure(figsize=(8, 8))
        columns = 3 
        rows = 4
        plt.figtext(0.5, 0.05, '3 columns represent: test image, automated segmentation and ground truth segmentation in order.', horizontalalignment='center',
             verticalalignment='top')
        for i, (image, label, output) in enumerate(zip(images, labels, merged_outputs)):
            figure.add_subplot(rows, columns, 3*i + 1)
            plt.imshow(image, cmap='gray')
            plt.gcf().set_size_inches(8, 8)
            figure.add_subplot(rows, columns, 3*i + 3)
            plt.imshow(output, cmap=colors.ListedColormap(['black', 'green', 'blue', 'red']))
            plt.gcf().set_size_inches(8, 8)
            figure.add_subplot(rows, columns, 3*i + 2)
            plt.imshow(label, cmap=colors.ListedColormap(['black', 'green', 'blue', 'red']))
            plt.gcf().set_size_inches(8, 8)
            

        plt.show()
        
        
loss_after_iterations = []
for i in range(1, 11):
    model.load_state_dict(torch.load(os.path.join(model_dir, 'model_{}000.pt'.format(i))))
    print("Model produced after {}000 iterations:".format(i))
    loss = criterion(torch.squeeze(output), torch.squeeze(labels))
    print("Test loss: {}".format(loss.item()))
    loss_after_iterations.append(loss.item())

    output = model(images)
    visualise(images, labels, output)
    
x = np.array(["{}000".format(i) for i in range(1, 11)])
y = np.array(loss_after_iterations)

print("Test error for each 1000 of iterations:")
plt.plot(x, y)
# Out:
# Model produced after 1000 iterations:
# Test loss: 0.07339885085821152
# Model produced after 2000 iterations:
# Test loss: 0.04648389667272568
# Model produced after 3000 iterations:
# Test loss: 0.043556008487939835
# Model produced after 4000 iterations:
# Test loss: 0.04642312973737717
# Model produced after 5000 iterations:
# Test loss: 0.061307840049266815
# Model produced after 6000 iterations:
# Test loss: 0.06703247129917145
# Model produced after 7000 iterations:
# Test loss: 0.05625559762120247
# Model produced after 8000 iterations:
# Test loss: 0.05728911980986595
# Model produced after 9000 iterations:
# Test loss: 0.07184261083602905
# Model produced after 10000 iterations:
# Test loss: 0.06005089357495308
# Test error for each 1000 of iterations:

# %% [markdown]
# ## 6. Discussion. Does your trained model work well? How would you improve this model so it can be deployed to the real clinic?
